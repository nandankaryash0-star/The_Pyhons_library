# %%
import pandas as pd
import numpy as np

# %%
mental_health = pd.read_csv('mental_health.csv')

# %%
mental_health
# Out:
#       Person_ID  Age  Gender  Occupation  Daily_Screen_Time  \
# 0             1   54    Male     Student               10.2
# 1             2   44    Male     Student                6.8
# 2             3   30    Male    Employed                5.5
# 3             4   58    Male    Employed                5.6
# 4             5   23  Female    Employed               10.1
# ...         ...  ...     ...         ...                ...
# 1995       1996   49  Female    Employed                4.8
# 1996       1997   33    Male    Employed                2.7
# 1997       1998   28    Male    Employed                2.6
# 1998       1999   56  Female     Student                3.2
# 1999       2000   38    Male  Unemployed                7.8
#
#       Social_Media_Usage  Night_Usage  Sleep_Hours  Stress_Level  \
# 0                    7.5            0          6.5             8
# 1                    4.5            0          5.1             4
# ...

# %%
mental_health[mental_health['Daily_Screen_Time'] >0.0].groupby('Occupation').min()
# Out:
#             Person_ID  Age  Gender  Daily_Screen_Time  Social_Media_Usage  \
# Occupation
# Employed            3   16  Female                2.0                 1.0
# Student             1   16  Female                2.0                 1.0
# Unemployed          7   16  Female                2.1                 1.0
#
#             Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours  \
# Occupation
# Employed              0          3.0             1               2.0
# Student               0          3.0             1               2.0
# Unemployed            0          3.0             1               2.0
#
#            Physical_Activity  Social_Interaction_Score  Caffeine_Intake  \
# Occupation
# Employed                High                         1                0
# Student                 High                         1                0
# Unemployed              High                         1                0
#
#             Smoking  Alcohol  Depression  Anxiety  Burnout
# ...
