# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('imdb-top-1000.csv')

# %%
movies.head(1)
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
#
#          Director        Star1  No_of_Votes       Gross  Metascore
# 0  Frank Darabont  Tim Robbins      2343110  28341469.0       80.0

# %%
#groupby -> catagory
genres =movies.groupby('Genre')
genres

# %%
genres.max()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# Family     Willy Wonka & the Chocolate Factory          1982      115
# Fantasy                              Nosferatu          1922       94
# Film-Noir                        The Third Man          1949      108
# Horror                               The Thing          2017      122
# Mystery                                Vertigo          2012      138
# ...

# %%
#find top 3 genres by total earning

movies.groupby('Genre').sum()['Gross'].sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
movies.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
movies.groupby('Director')['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Director
# Akira Kurosawa      3.070432e+09
# Steven Spielberg    2.478133e+09
# Hayao Miyazaki      2.447325e+09
# Name: Gross, dtype: float64

# %%
# find the genre with highest avg IMDB rating

movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False).head(3)
# Out:
# Genre
# Western    8.350000
# Crime      8.016822
# Fantasy    8.000000
# Name: IMDB_Rating, dtype: float64

# %%
# find the genre with highest IMDB rating

movies.groupby('Genre')['IMDB_Rating'].max().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     9.3
# Crime     9.2
# Action    9.0
# Name: IMDB_Rating, dtype: float64

# %%
# find director with most popularity
movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False).head(3)
# Out:
# Director
# Christopher Nolan    11578345
# Quentin Tarantino     8123208
# Steven Spielberg      7817166
# Name: No_of_Votes, dtype: int64

# %%
movies.groupby('Director')['Metascore'].sum().sort_values(ascending=False).head(3)
# Out:
# Director
# Alfred Hitchcock    1270.0
# Steven Spielberg    1047.0
# Hayao Miyazaki       908.0
# Name: Metascore, dtype: float64

# %%
# find the highest rated movie of each genre

max_ratings = movies.groupby('Genre')['IMDB_Rating'].transform('max')

all_top_movies = movies[movies['IMDB_Rating'] == max_ratings]

all_top_movies
# Out:
#                             Series_Title Released_Year  Runtime      Genre  \
# 0               The Shawshank Redemption          1994      142      Drama
# 1                          The Godfather          1972      175      Crime
# 2                        The Dark Knight          2008      152     Action
# 7                       Schindler's List          1993      195  Biography
# 12       Il buono, il brutto, il cattivo          1966      161    Western
# 19                          Gisaengchung          2019      132     Comedy
# 21                          Interstellar          2014      169  Adventure
# 23         Sen to Chihiro no kamikakushi          2001      125  Animation
# 26                       La vita è bella          1997      116     Comedy
# 49                                Psycho          1960      109     Horror
# 69                               Memento          2000      113    Mystery
# ...

# %%
 #find number of movies done by each actor

movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks             12
# Robert De Niro        11
# Clint Eastwood        10
# Al Pacino             10
# Leonardo DiCaprio      9
#                       ..
# Glen Hansard           1
# Giuseppe Battiston     1
# Giulietta Masina       1
# Gerardo Taracena       1
# Ömer Faruk Sorak       1
# Name: Series_Title, Length: 660, dtype: int64

# %%
# GroupBy Attributes and Methods
# find total number of groups -> len
# find items in each group -> size
# first()/last() -> nth item
# get_group -> vs filtering
# groups
# describe
# sample
# nunique

# %%
len(movies.groupby('Genre'))
# Out:
# 14

# %%
movies.groupby('Genre').size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
genres.nth(100)
# Out:
#                       Series_Title Released_Year  Runtime   Genre  \
# 319  Sunrise: A Song of Two Humans          1927       94   Drama
# 625                     Apocalypto          2006      139  Action
# 704                   Mary Poppins          1964      139  Comedy
# 939            Boksuneun naui geot          2002      129   Crime
#
#      IMDB_Rating          Director             Star1  No_of_Votes  \
# 319          8.1       F.W. Murnau    George O'Brien        46865
# 625          7.8        Mel Gibson  Gerardo Taracena       291018
# 704          7.8  Robert Stevenson     Julie Andrews       158029
# 939          7.6    Chan-wook Park      Kang-ho Song        62659
#
#            Gross  Metascore
# 319     539540.0        NaN
# 625   50866635.0       68.0
# 704  102272727.0       88.0
# 939      45289.0       56.0

# %%
genres = movies.groupby('Genre')

# %%
genres.last()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
genres.last()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
genres.nth(6)
# Out:
#                                        Series_Title Released_Year  Runtime  \
# 16   Star Wars: Episode V - The Empire Strikes Back          1980      124
# 27                                            Se7en          1995      127
# 32                            It's a Wonderful Life          1946      130
# 66                                           WALL·E          2008       98
# 83                               The Great Dictator          1940      125
# 102                                      Braveheart          1995      178
# 118                              North by Northwest          1959      136
# 420                                          Sleuth          1972      138
# 724                                         Get Out          2017      104
#
#          Genre  IMDB_Rating              Director             Star1  \
# 16      Action          8.7        Irvin Kershner       Mark Hamill
# 27       Crime          8.6         David Fincher    Morgan Freeman
# ...

# %%
genres.get_group('Fantasy') #fast
# Out:
#                      Series_Title Released_Year  Runtime    Genre  \
# 321  Das Cabinet des Dr. Caligari          1920       76  Fantasy
# 568                     Nosferatu          1922       94  Fantasy
#
#      IMDB_Rating      Director          Star1  No_of_Votes        Gross  \
# 321          8.1  Robert Wiene  Werner Krauss        57428  337574718.0
# 568          7.9   F.W. Murnau    Max Schreck        88794  445151978.0
#
#      Metascore
# 321        NaN
# 568        NaN

# %%
movies[movies['Genre'] == 'Fantasy']
# Out:
#                      Series_Title Released_Year  Runtime    Genre  \
# 321  Das Cabinet des Dr. Caligari          1920       76  Fantasy
# 568                     Nosferatu          1922       94  Fantasy
#
#      IMDB_Rating      Director          Star1  No_of_Votes        Gross  \
# 321          8.1  Robert Wiene  Werner Krauss        57428  337574718.0
# 568          7.9   F.W. Murnau    Max Schreck        88794  445151978.0
#
#      Metascore
# 321        NaN
# 568        NaN

# %%
genres.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
genres.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
genres.sample(2,replace=True)
# Out:
#                             Series_Title Released_Year  Runtime      Genre  \
# 362                 The Bourne Ultimatum          2007      115     Action
# 356                       Tropa de Elite          2007      115     Action
# 513                      Children of Men          2006      109  Adventure
# 537                   La montaña sagrada          1973      114  Adventure
# 875                             Fantasia          1940      125  Animation
# 694                   La planète sauvage          1973       72  Animation
# 858                A Man for All Seasons          1966      120  Biography
# 18                              Hamilton          2020      160  Biography
# 471                    Captain Fantastic          2016      118     Comedy
# 494                            In Bruges          2008      107     Comedy
# 363                              Bin-jip          2004       88      Crime
# ...

# %%
genres.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
#agg method 
#passing dict
genres.agg(
    {
        'Runtime':'mean',
        'IMDB_Rating':'mean',
        'No_of_Votes':'sum',
        'Metascore':'mean'
    }
)
# Out:
#               Runtime  IMDB_Rating  No_of_Votes  Metascore
# Genre
# Action     129.046512     7.949419     72282412  73.419580
# Adventure  134.111111     7.937500     22576163  78.437500
# Animation   99.585366     7.930488     21978630  81.093333
# Biography  136.022727     7.938636     24006844  76.240506
# Comedy     112.129032     7.901290     27620327  78.720000
# Crime      126.392523     8.016822     33533615  77.080460
# Drama      124.737024     7.957439     61367304  79.701245
# Family     107.500000     7.800000       551221  79.000000
# Fantasy     85.000000     8.000000       146222        NaN
# Film-Noir  104.000000     7.966667       367215  95.666667
# Horror     102.090909     7.909091      3742556  80.000000
# Mystery    119.083333     7.975000      4203004  79.125000
# Thriller   108.000000     7.800000        27733  81.000000
# Western    148.250000     8.350000      1289665  78.250000

# %%
#passing list 
genres.agg(['min', 'max', 'count'])
# Out:
#                               Series_Title  \
#                                        min
# Genre
# Action                                 300
# Adventure            2001: A Space Odyssey
# Animation                            Akira
# Biography                 12 Years a Slave
# Comedy                (500) Days of Summer
# Crime                         12 Angry Men
# Drama                                 1917
# Family          E.T. the Extra-Terrestrial
# Fantasy       Das Cabinet des Dr. Caligari
# Film-Noir                Shadow of a Doubt
# Horror                               Alien
# Mystery                          Dark City
# Thriller                   Wait Until Dark
# Western    Il buono, il brutto, il cattivo
#
#                                                      Released_Year        \
#                                            max count           min   max
# Genre
# Action                                 Yôjinbô   172          1924  2019
# ...

# %%
#agg method 
#passing dict
#adding both the syntax

genres.agg(
    {
        'Runtime':['mean','min'],
        'IMDB_Rating':['mean','min'],
        'No_of_Votes':['sum','max'],
        'Metascore':'mean'
    }
)
# Out:
#               Runtime      IMDB_Rating      No_of_Votes           Metascore
#                  mean  min        mean  min         sum      max       mean
# Genre
# Action     129.046512   45    7.949419  7.6    72282412  2303232  73.419580
# Adventure  134.111111   88    7.937500  7.6    22576163  1512360  78.437500
# Animation   99.585366   71    7.930488  7.6    21978630   999790  81.093333
# Biography  136.022727   93    7.938636  7.6    24006844  1213505  76.240506
# Comedy     112.129032   68    7.901290  7.6    27620327   939631  78.720000
# Crime      126.392523   80    8.016822  7.6    33533615  1826188  77.080460
# Drama      124.737024   64    7.957439  7.6    61367304  2343110  79.701245
# Family     107.500000  100    7.800000  7.8      551221   372490  79.000000
# Fantasy     85.000000   76    8.000000  7.9      146222    88794        NaN
# Film-Noir  104.000000  100    7.966667  7.8      367215   158731  95.666667
# ...

# %%
df = pd.DataFrame(columns = movies.columns)
for group,data in genres:
    df.append(data[data['IMDB_Rating'] == data['IMDB_Rating'].max()])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mc/sfhtpvd52p98f218ysdxkwy00000gn/T/ipykernel_2852/783277449.py in ?()
#       1 df = pd.DataFrame(columns = movies.columns)
#       2 for group,data in genres:
# ----> 3     df.append(data[data['IMDB_Rating'] == data['IMDB_Rating'].max()])
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ai_dev/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
#split (apply) combine 
#apply -> buit in function

genres.apply(min)

# %%
genres.min()

# %%
# looping on groups
results = []
for group,data in genres:
    highest_rated = data[data['IMDB_Rating'] == data['IMDB_Rating'].max()]
    results.append(highest_rated)

df = pd.concat(results, ignore_index=True)
df

# %%
# looping of group
df = pd.DataFrame(columns=movies.columns)
print(df)
for group,data in genres:
    df = df.append(data[data['IMDB_Rating'] == data['IMDB_Rating'].max()])

df

# %%
genres.get_group('Horror')

# %%
combo_group = movies.groupby(['Director','Star1'])
combo_group.size()

# %%
genres.get_group('Fantasy')

# %%
genres.groups

# %%
genres.describe()

# %%
genres.sample(1)

# %%
genres.nunique()

# %%
# how to use loop
top_movies = []
df = pd.DataFrame(columns=movies.columns)
print(df)
for group,data in genres:
    best_movie = data[data['IMDB_Rating'] ==  data['IMDB_Rating'].max()]
    top_movies.append(best_movie)
    
    df = pd.concat(top_movies,ignore_index=True)

df

# %%
#split apply combine
#apply -> builtin functions 

genres.apply(max)

# %%
genres = movies.groupby('Genre')
genres.apply(min)

# %%
def foo (group):
    print(group)
    return group

genres.apply(foo)

# %%
def foo (group):    
    return group['Series_Title'].str.startswith("A").sum()    

genres.apply(foo)

# %%
def ranking_movie(group):
    group['IMDB_Rating'] = group['IMDB_Rating'].rank(ascending=False)
    return group

# %%
genres.apply(ranking_movie)

# %%
def normal(group):
    group['norm_rating'] = (group['IMDB_Rating'] - group['IMDB_Rating'].min()) / (group['IMDB_Rating'].max() - group['IMDB_Rating'].min())
    return group

genres.apply(normal)


#apply custome logic apply

# %%
#group on multiple colums 
duo = movies.groupby(['Director','Star1'])
duo.size()

# %%
duo.get_group(('Aaron Sorkin','Eddie Redmayne'))
duo['Gross'].sum().sort_values(ascending=False).head(1)

# %%
movies.groupby(['Star1','Genre'])['Metascore'].mean().reset_index().sort_values('Metascore',ascending=False)

# %%
duo.agg(['min','max'])

# %%
ipl = pd.read_csv('deliveries.csv')
ipl
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  str
#  3   bowling_team      179078 non-null  str
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  str
#  7   non_striker       179078 non-null  str
#  8   bowler            179078 non-null  str
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
ipl.shape

# %%
#find top 10 batsman in terms of run

ipl.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
six_runs = ipl[ipl['batsman_runs'] == 6]

# %%
six_runs.groupby('batsman')['batsman'].count().sort_values(ascending=False)
# Out:
# batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
#                  ...
# CK Langeveldt       1
# JDS Neesham         1
# SK Trivedi          1
# D Shorey            1
# MN van Wyk          1
# Name: batsman, Length: 336, dtype: int64

# %%
last_over = ipl[ipl['over'] > 15]
last_over[(last_over['batsman_runs'] ==4 ) | (last_over['batsman_runs'] == 6)]
last_over.groupby('batsman')['batsman'].count().sort_values(ascending=False)
# Out:
# batsman
# MS Dhoni          1548
# KA Pollard         967
# RG Sharma          818
# YK Pathan          732
# RA Jadeja          707
#                   ...
# NJ Rimmington        1
# V Pratap Singh       1
# Sunny Gupta          1
# A Mukund             1
# DT Patil             1
# Name: batsman, Length: 465, dtype: int64

# %%
# find V kohli's record against all team
temp_df = ipl[ipl['batsman'] == 'V Kohli']

temp_df.groupby('bowling_team')['batsman_runs'].sum().reset_index()
# Out:
#                bowling_team  batsman_runs
# 0       Chennai Super Kings           749
# 1           Deccan Chargers           306
# 2            Delhi Capitals            66
# 3          Delhi Daredevils           763
# 4             Gujarat Lions           283
# 5           Kings XI Punjab           636
# 6      Kochi Tuskers Kerala            50
# 7     Kolkata Knight Riders           675
# 8            Mumbai Indians           628
# 9             Pune Warriors           128
# 10         Rajasthan Royals           370
# 11   Rising Pune Supergiant            83
# 12  Rising Pune Supergiants           188
# 13      Sunrisers Hyderabad           509

# %%
#creates a function that can return the highest score of any batsman

temp_df = ipl[ipl['batsman'] == 'MS Dhoni']
temp_df.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1)
# Out:
# match_id
# 11330    89
# Name: batsman_runs, dtype: int64

# %%
def highest_score (batsman):
    temp_df = ipl[ipl['batsman'] == 'batsman']
    temp_df.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1).values[0]

highest_score('MS Dhoni')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[126], line 5
#       2     temp_df = ipl[ipl['batsman'] == 'batsman']
#       3     temp_df.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1).values[0]
# ----> 5 highest_score('MS Dhoni')
#
# Cell In[126], line 3, in highest_score(batsman)
#       1 def highest_score (batsman):
#       2     temp_df = ipl[ipl['batsman'] == 'batsman']
# ----> 3     temp_df.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1).values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
