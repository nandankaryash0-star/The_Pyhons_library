# %%
import pandas as pd
import numpy as np

# %%
student = pd.read_csv('StudentsPerformance.csv')

# %%
student
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race/ethnicity               1000 non-null   str
#  2   parental level of education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test preparation course      1000 non-null   str
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), str(5)
# memory usage: 103.5 KB

# %%
student.groupby("gender")["math score"].mean()
# Out:
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
student[['math score','reading score','writing score']].mean()
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
student['total'] = student[['math score','reading score','writing score']].sum(axis=1)

topper = student.sort_values(by='total',ascending=False)

topper.head(1)
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 916   male        group E           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score  total
# 916               completed         100            100            100    300

# %%
#Find the topper (highest math score)

student.sort_values(by='math score',ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  total
# ...

# %%
student[student['math score']>90]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 171    male        group E            some high school      standard
# 179  female        group D            some high school      standard
# 233    male        group E            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# ...

# %%
student
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  total
# ...

# %%
student[student['total']>250].groupby('race/ethnicity').max()
# Out:
#                gender parental level of education     lunch  \
# race/ethnicity
# group A          male            some high school  standard
# group B          male            some high school  standard
# group C          male            some high school  standard
# group D          male            some high school  standard
# group E          male            some high school  standard
#
#                test preparation course  math score  reading score  \
# race/ethnicity
# group A                           none         100            100
# group B                           none          97             97
# group C                           none          98            100
# group D                           none         100            100
# group E                           none         100            100
#
#                 writing score  total
# race/ethnicity
# group A                    97    289
# group B                    96    290
# group C                   100    296
# ...

# %%
student[student['total']>250].groupby('race/ethnicity').min()
# Out:
#                 gender parental level of education         lunch  \
# race/ethnicity
# group A         female          associate's degree      standard
# group B         female          associate's degree  free/reduced
# group C         female          associate's degree  free/reduced
# group D         female          associate's degree  free/reduced
# group E         female          associate's degree  free/reduced
#
#                test preparation course  math score  reading score  \
# race/ethnicity
# group A                      completed          78             84
# group B                      completed          74             84
# group C                      completed          77             79
# group D                      completed          74             81
# group E                      completed          79             82
#
#                 writing score  total
# race/ethnicity
# group A                    86    256
# group B                    84    251
# ...

# %%
student.groupby('race/ethnicity')['total'].mean()
# Out:
# race/ethnicity
# group A    188.977528
# group B    196.405263
# group C    201.394984
# group D    207.538168
# group E    218.257143
# Name: total, dtype: float64

# %%
student[student['total']>250].groupby('parental level of education').max()
# Out:
#                             gender race/ethnicity     lunch  \
# parental level of education
# associate's degree            male        group E  standard
# bachelor's degree             male        group E  standard
# high school                   male        group E  standard
# master's degree               male        group E  standard
# some college                  male        group E  standard
# some high school              male        group E  standard
#
#                             test preparation course  math score  \
# parental level of education
# associate's degree                             none         100
# bachelor's degree                              none         100
# high school                                    none          99
# master's degree                                none          95
# some college                                   none         100
# some high school                               none          97
#
# ...

# %%
student[student['total']>250].groupby('parental level of education').min()
# Out:
#                              gender race/ethnicity         lunch  \
# parental level of education
# associate's degree           female        group A  free/reduced
# bachelor's degree            female        group A  free/reduced
# high school                  female        group B      standard
# master's degree              female        group B  free/reduced
# some college                 female        group A  free/reduced
# some high school             female        group A  free/reduced
#
#                             test preparation course  math score  \
# parental level of education
# associate's degree                        completed          74
# bachelor's degree                         completed          77
# high school                               completed          81
# master's degree                           completed          77
# some college                              completed          77
# some high school                          completed          74
# ...

# %%
student
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  total
# ...

# %%
student[student['writing score']>80].count(axis=0)
# Out:
# gender                         208
# race/ethnicity                 208
# parental level of education    208
# lunch                          208
# test preparation course        208
# math score                     208
# reading score                  208
# writing score                  208
# total                          208
# dtype: int64

# %%
student.groupby('gender')['total'].mean()
# Out:
# gender
# female    208.708494
# male      197.512448
# Name: total, dtype: float64
