# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns

plt.style.use('default')

# %%
#Types of data
# Numerical data 
# Categorical data

# %%
#plotting a simple graph

price = [4800,5400,4500,4700,50000]
year = [2015,2016,2017,1018,2019]
plt.plot(price,year)

# %%
batsman = pd.read_csv('sharma-kohli.csv')
batsman
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(batsman['index'],batsman['V Kohli'])

# %%
#plotting multiple plots

plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])

plt.title('Comparision between Rohit Sharma as V kohli')
plt.xlabel('Seasons')
plt.ylabel('Run Score')
# Out:
# Text(0, 0.5, 'Run Score')
